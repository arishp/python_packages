# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.thehindu.com/"
response = requests.get(url)

# %%
response.content
# Out:
# b'<!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" lang="en" ><head><title>\n\tBreaking News Today, Top Headlines, Live Updates | The Hindu\n</title><meta charset="utf-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="viewport" content="width=device-width,initial-scale=1"><meta name="title" content="Breaking News Today, Top Headlines, Live Updates" /><meta name="description" content="Today\xe2\x80\x99s News Headlines, Breaking News &amp;amp; Latest News from India and World, News from Politics, Sports, Business, Arts and Entertainment" /><meta name="keywords" content="News, Latest News, Breaking News, Live News, World News today, Latest Business News, India News, News online, News Headlines, News Today, Top Stories, Online news"/><meta name="robots" content="index, follow"/><meta name="robots" content="max-image-preview:large"><meta name="atdlayout" content="homepage" /><meta name="twitter:title" content="Breaking News Today, Top Headlines, Li
# ...

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
titles = [item.text.strip() for item in soup.find_all("h2")] #Change to your website structure.

# %%
titles
# Out:
# ['Clashes erupt, vehicles torched during Holi procession in Jharkhand’s Giridih',
#  'Did not want PM Modi, world leaders to see tents, graffiti, potholes in Washington: Trump',
#  'Mark Carney sworn in as Canada’s new Prime Minister amid Trump’s trade war',
#  'Latest News',
#  'Top Videos',
#  'Top Picks',
#  'The Hindu Opinion',
#  'The Hindu Explains',
#  'Top News Today',
#  'Featured',
#  'States Updates',
#  'Cities Updates']

# %%
# HTML CODE 
html_code = """<a><b>text1</b><c>text2</c></a>"""

# Parse HTML CODE 
soup = BeautifulSoup(html_code, 'html.parser') 

# next element 
print(soup.b.next_sibling)
# Out:
# <c>text2</c>

# %%
# previous element 
print(soup.c.previous_sibling)
# Out:
# <b>text1</b>

# %%
# Import Module 
from bs4 import BeautifulSoup 
import requests 

# Website URL 
URL = 'https://www.geeksforgeeks.org/'

# class list set 
class_list = set() 

# Page content from Website URL 
page = requests.get( URL ) 

# parse html content 
soup = BeautifulSoup( page.content , 'html.parser') 

# get all tags 
tags = {tag.name for tag in soup.find_all()} 

# iterate all tags 
for tag in tags: 

	# find all element of tag 
	for i in soup.find_all( tag ): 

		# if tag has attribute of class 
		if i.has_attr( "class" ): 

			if len( i['class'] ) != 0: 
				class_list.add(" ".join( i['class'])) 

print( class_list )
# Out:
# {'HomePageCourseCard_homePageCourseCard_textContainer_level__2nbvZ', 'HomePageTopicCard_homePageTopicCard__eePhS row4', 'HomePageSectionHeader_homePageSectionHeader__Gdp6s viewAll_articles', 'HomePageSectionHeader_homePageSectionHeader--cta__aRzJv home_viewall_row5', 'HomePageArticleCard_homePageArticleCard--cta__CUjXy', 'HomePageGateCourseBanner_courseBannerContainer__DPtui', 'rightIcon icon', 'HomePageTopicCard_homePageTopicCard__eePhS row11', 'HomePageTopicCard_homePageTopicCard__eePhS row6', 'HomePageCourseCard_homePageCourseCard_textContainer_container_geeksCount--icon_box__brFa3', 'HomePageTopicCard_homePageTopicCard__eePhS row7', 'HomePageSectionHeader_homePageSectionHeader__Gdp6s viewAll_courses', 'footer-container_address_header', 'footer-container_address_content', 'footer-container_branding-logo-container', 'HomePageSectionHeader_homePageSectionHeader--cta__aRzJv home_viewall_row4', 'HomePageTopicCard_homePageTopicCard_button--icon__VYq8d', 'gfgheader_parentContainer', 'Se
# ...

# %%
from bs4 import BeautifulSoup
import requests

# sample web page
sample_web_page = 'https://www.geeksforgeeks.org/caching-page-tables/'

# call get method to request that page
page = requests.get(sample_web_page)

# with the help of beautifulSoup and html parser create soup
soup = BeautifulSoup(page.content, "html.parser")

child_soup = soup.find_all('strong')

text = 'page table base register (PTBR)'

# we will search the tag with in which text is same as given text
for i in child_soup:
	if(i.string == text):
		print(i)
# Out:
# <strong>page table base register (PTBR)</strong>

# %%
# Function to append new tag 
def addTag(html): 

	# parse html content 
	soup = BeautifulSoup(html, "html.parser") 

	# create new tag 
	# Here we are creating a new div 
	new_div = soup.new_tag("div") 

	# Adding content to div 
	new_div.string = " This is new div "

	# Appending new div to html tree 
	soup.html.body.append(new_div) 

	# Printing the modified object 
	print(soup)

# %%
# HTML Document 
HTML_DOC = """ 
			<html> 
			<head> 
				<title> Add new Tag </title> 
			</head> 
			<body> 
					<div> This is sample div 1 </div> 
					<div> This is sample div 2 </div> 
			</body> 
			</html> 
			"""


# Function Call 
addTag(HTML_DOC)
# Out:
# <html>
# <head>
# <title> Add new Tag </title>
# </head>
# <body>
# <div> This is sample div 1 </div>
# <div> This is sample div 2 </div>
# <div> This is new div </div></body>
# </html>

# %%
import sqlite3

# Connect to SQLite database (or create one if it doesn't exist)
conn = sqlite3.connect("/Users/apitchai002/Documents/Clones/python_packages/sample.db")

# Create a cursor object
cursor = conn.cursor()

# Create a table
cursor.execute("""
CREATE TABLE IF NOT EXISTS users (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT NOT NULL,
    age INTEGER,
    email TEXT UNIQUE
)
""")

# Commit changes and close the connection
conn.commit()
conn.close()
print("Database and table created successfully.")
# Out:
# Database and table created successfully.

# %%
conn = sqlite3.connect("/Users/apitchai002/Documents/Clones/python_packages/sample.db")
cursor = conn.cursor()

# Insert sample data
cursor.execute("INSERT INTO users (name, age, email) VALUES (?, ?, ?)", 
               ("Alice", 25, "alice@example.com"))
cursor.execute("INSERT INTO users (name, age, email) VALUES (?, ?, ?)", 
               ("Bob", 30, "bob@example.com"))
cursor.execute("INSERT INTO users (name, age, email) VALUES (?, ?, ?)", 
               ("Charlie", 36, "charlie@example.com"))
cursor.execute("INSERT INTO users (name, age, email) VALUES (?, ?, ?)", 
               ("Daisy", 20, "daisy@example.com"))
cursor.execute("INSERT INTO users (name, age, email) VALUES (?, ?, ?)", 
               ("Emily", 63, "emily@example.com"))

# Commit and close
conn.commit()
conn.close()
print("Data inserted successfully.")
# Out:
# Data inserted successfully.

# %%
conn = sqlite3.connect("/Users/apitchai002/Documents/Clones/python_packages/sample.db")
cursor = conn.cursor()

# Retrieve all records
cursor.execute("SELECT * FROM users")
rows = cursor.fetchall()

# Print results
print("Users in the database:")
for row in rows:
    print(row)

conn.close()
# Out:
# Users in the database:
# (1, 'Alice', 25, 'alice@example.com')
# (2, 'Bob', 30, 'bob@example.com')
# (3, 'Charlie', 36, 'charlie@example.com')
# (4, 'Daisy', 20, 'daisy@example.com')
# (5, 'Emily', 63, 'emily@example.com')

# %%
conn = sqlite3.connect("/Users/apitchai002/Documents/Clones/python_packages/sample.db")
cursor = conn.cursor()

# Retrieve users older than 25
cursor.execute("SELECT * FROM users WHERE age > ?", (25,))
rows = cursor.fetchall()

print("Users older than 25:")
for row in rows:
    print(row)

conn.close()
# Out:
# Users older than 25:
# (2, 'Bob', 30, 'bob@example.com')
# (3, 'Charlie', 36, 'charlie@example.com')
# (5, 'Emily', 63, 'emily@example.com')

# %%
conn = sqlite3.connect("/Users/apitchai002/Documents/Clones/python_packages/sample.db")
cursor = conn.cursor()

# Update user’s age
cursor.execute("UPDATE users SET age = ? WHERE name = ?", (28, "Alice"))

# Commit and close
conn.commit()
conn.close()
print("User's age updated successfully.")
# Out:
# User's age updated successfully.

# %%
conn = sqlite3.connect("/Users/apitchai002/Documents/Clones/python_packages/sample.db")
cursor = conn.cursor()

# Delete a user by name
cursor.execute("DELETE FROM users WHERE name = ?", ("Bob",))

# Commit and close
conn.commit()
conn.close()
print("User deleted successfully.")
# Out:
# User deleted successfully.

# %%
import pandas as pd

conn = sqlite3.connect("/Users/apitchai002/Documents/Clones/python_packages/sample.db")
query = "SELECT * FROM users"

# Read into a DataFrame
df = pd.read_sql_query(query, conn)

print(df)

conn.close()
# Out:
#    id     name  age                email
# 0   1    Alice   28    alice@example.com
# 1   3  Charlie   36  charlie@example.com
# 2   4    Daisy   20    daisy@example.com
# 3   5    Emily   63    emily@example.com
